# %%
# MicrosoftFoundry/GettingStarted/OpenAI_Chat_Completions
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
project_client = AIProjectClient(
    endpoint=foundry_project_endpoint,
    credential=DefaultAzureCredential()
)
openai_client = project_client.get_openai_client()

# %%
# MicrosoftFoundry/GettingStarted/Foundry_Catalog_Completions/chat_completions.ipynb
# %pip install anthropic==0.75.0 python-dotenv
from anthropic import AnthropicFoundry
client = AnthropicFoundry(
    api_key=api_key,
    base_url=model_endpoint,
)

message = client.messages.create(
   
)

# %%
# MicrosoftFoundry/AgentService
# MicrosoftFoundry/AgentService/Code_Interpreter/code_interpreter.ipynb

# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity
